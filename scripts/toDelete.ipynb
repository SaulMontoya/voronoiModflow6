# %%
from vorModflow.geoVoronoi import createVoronoi
import matplotlib.pyplot as plt
import geopandas as gpd
import numpy as np

import time

#Create mesh object
vorMesh = createVoronoi()

#Define base refinement and refinement levels
vorMesh.defineParameters(maxRef = 500, refLevel=3, refTimes = 1)

#Open limit layers and refinement definition layers
vorMesh.addLimitLayer('basin','../shps/Angascancha_Basin_Extension.shp')
vorMesh.addDiscretizationLayer('river','../shps/rios.shp')

#Generate point pair array
vorMesh.domainPairArray( txtFile='../txt/pairArray.txt')

#Relaxation of voronoi polygons
vorMesh.relaxVertices()
#vorMesh.relaxVertices()
#vorMesh.relaxVertices()
# Out:
# /--------Sumary of cell discretization-------/
# Maximun refinement: 500.00 m.
# Minimum refinement: 166.67 m.
# /--------------------------------------------/
# Filling points with refinement of 500.00 m: 100%|████████████████████████████████| 2530/2530 [00:01<00:00, 1868.53it/s]
# /----Sumary of points for voronoi meshing----/
# Points from limit layers: 151
# Points from definition layers: 2427
# Total number of generated points: 7447
# /--------------------------------------------/
#
# Time required for point generation: 1.45 seconds
#
# Time required for Voronoi relaxation: 1.32 seconds

# %%
#Create polygon object and clip to the limit layer
vorGraph = vorMesh.createClipVoronoi(shapePath='../shps/voronoiGridRelaxed2.shp')
# Out:
# /---------Sumary of voronoi meshing----------/
# Total number of cells: 5906
# Area of 95 percentile cell: 120208.93 m2
# Area of 50 percent (median) cell: 30360.37 m2
# Area of 5 percentile cell: 27755.50 m2
# /---------------------------------------------/
#
# Time required for Voronoi clipping: 2.08 seconds

# %%
vorGraph.plot()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-a50129f1eba2> in <module>
# ----> 1 vorGraph.plot()
#
# AttributeError: 'Figure' object has no attribute 'plot'
